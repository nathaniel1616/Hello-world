# %%
import csv 
import numpy as np
from tensorflow.keras.preprocessing.image import array_to_img
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
test_file_path =r"C:\Users\Nat\Downloads\Compressed\sign_mnist_test\sign_mnist_test.csv"
train_file_path =r"C:\Users\Nat\Downloads\Compressed\sign_mnist_train\sign_mnist_train.csv"

# %%
df = pd.read_csv(train_file_path)
print(df.head(
label = df['label']

pixels = df.drop('label',axis=1)
pixels.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  ...  pixel779  pixel780  pixel781  pixel782  pixel783  pixel784
# 0      3     107     118     127     134     139  ...       206       206       206       204       203       202
# 1      6     155     157     156     156     156  ...        94       163       175       103       135       149
# 2      2     187     188     188     187     187  ...       198       199       198       195       194       195
# 3      2     211     211     212     212     211  ...       230       226       225       222       229       163
# 4     13     164     167     170     172     176  ...       133       163       157       163       164       179
#
# [5 rows x 785 columns]

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
train_datagen.flow_from_dataframe(df,)

# %%
pixels= pixels.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-2b82037ab50a> in <module>
#       1 pixels= pixels.to_numpy()
# ----> 2 pixels.reshape(274555,28,28)
#
# ValueError: cannot reshape array of size 21524720 into shape (274555,28,28)

# %%
pixels.shape
# Out:
# (27455, 784)

# %%
array_to_img(pixels[0].reshape(28,28,1))
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x1212E4E1F10>

# %%
label = label.to_numpy()
pixels= pixels.to_numpy()
# Out:
# array([ 3,  6,  2, ..., 18, 17, 23], dtype=int64)
